# %% [markdown]
# # Simple Calculator
# Lengkapilah kode berikut untuk membuat program sederhana yang dapat melakukan operasi penjumlahan, pengurangan, perkalian, pembagian, pangkat, dan akar dua angka integer berdasarkan input pengguna. <br />
# Program akan terus meminta masukan pengguna hingga pengguna memasukkan 'exit' sebagai input.

# %%
# import libraries here if needed...

# %%
def add(a, b):
  """Fungsi untuk operasi penjumlahan a+b"""
  c=a+b
  
  return (a + b)

def sub(a, b):
  """Fungsi untuk operasi pengurangan a-b"""
  c=a-b
   
  return (a - b)

def mul(a, b):
  """Fungsi untuk operasi perkalian a*b"""
  c=a*b
 
  return (a * b)

def div(a, b):
  """Fungsi untuk operasi pembagian a/b"""
  c=a/b
 
  return (a / b)

def exp(a, b):
  """Fungsi untuk operasi pangkat a^b"""
  c=a^b
 
  return (a ** b)
  
def root(a,b):
  """Fungsi untuk operasi akar b√a"""
  c=( (1 // a) ** b )
  
  return (  (1 // a) ** b )

#def input_num():
  """Fungsi untuk meminta masukan angka dari pengguna"""
  # HINT: bisa menggunakan fungsi split() untuk multiple inputs in one line dan 
  #       konsep list comprehension
  #Angka = input("Masukan angka: ")

  #return (a,b,c)

# %%
def main():
  x_list = ("add", "sub", "mul", "div", "exp", "root", "exit")
  # cetak list perintah dengan format <nomor>.<spasi><perintah><enter>
  # contoh: 1. add
  #         2. sub
  #         ...
  # YOUR CODE HERE
print ("Select an operation you wanna use")
print ("1. add")
print ("2. sub")
print ("3. mul")
print ("4. div")
print ("5. exp")
print ("6. root")
print ("7. exit")

  #command = input ("Masukkan perintah: ")
  #print(command)
  #while command != "exit":

    #if command == "add":
      #a, b = input_num()
      #result = add(a,b)
      #print("Hasil penjumlahan adalah {}.\n".format(result))
    
    # lengkapi untuk semua operasi
    # jika input pengguna tidak sesuai, cetak "Perintah tidak valid!" ke layar 
    # YOUR CODE HERE

    #command = input("Masukkan perintah: ")
  #print("Exiting... Done.")


command = input ("Masukkan jenis operasi add,sub,mul,div,exp,root,exit  : ")


if command == "add":
    a = float(input("Nilai a: "))
    b = float(input("Nilai b: "))
    c= add(a,b)
    print("Hasil penjumlahan adalah {}.\n".format(c))
elif command == "sub":
    a = float(input("Nilai a: "))
    b = float(input("Nilai b: "))
    c= sub(a,b)
    print("Hasil pengurangan adalah {}.\n".format(c))
elif command == "mul":
    a = float(input("Nilai a: "))
    b = float(input("Nilai b: "))
    c= mul(a,b)
    print("Hasil perkalian adalah {}.\n".format(c))
elif command == "div":
    a = float(input("Nilai a: "))
    b = float(input("Nilai b: "))
    c= div(a,b)
    print("Hasil pembagian adalah {}.\n".format(c))
elif command == "exp":
    a = float(input("Nilai a: "))
    b = float(input("Nilai b: "))
    c= exp(a,b)
    print("Hasil pangkat adalah {}.\n".format(c))
elif command == "root":
    a = float(input("Nilai a: "))
    b = float(input("Nilai b: "))
    c= root(a,b)
    print("Hasil akar adalah {}.\n".format(c))
else:
    print("Perintah tidak valid!")

#command = input("Masukkan perintah: ")
#  print("Exiting... Done.")

# %%
if __name__ == "__main__":
  main()
